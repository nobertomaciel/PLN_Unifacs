# %% [markdown]
# # Análise de Sentimentos com LSTM

# %%
# !pip install transformers torch sentencepiece -q

# %%
import pandas as pd
from transformers import pipeline

# %%
sentimentos = pipeline(
    "text-classification",
    model="lxyuan/distilbert-base-multilingual-cased-sentiments-student",
    truncation=True
)
# Out:
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]

# %%
frase = "Gostei muito do produto."
resultado = sentimentos(frase)
print(resultado)
# Out:
# [{'label': 'positive', 'score': 0.7132254242897034}]

# %%
frases = [
    "Gostei muito do produto.",
    "O atendimento foi excelente.",
    "A câmera é fantástica.",
    "Não gostei do serviço.",
    "Muito ruim.",
    "O celular estragou em dois dias.",
    "Excelente custo-benefício.",
    "Jamais compraria novamente."
]

for frase in frases:
    r = sentimentos(frase)[0]
    print(f"{frase}")
    print(f"Sentimento: {r['label']}")
    print(f"Confiança: {r['score']:.3f}")
    print()
# Out:
# Gostei muito do produto.
# Sentimento: positive
# Confiança: 0.713
#
# O atendimento foi excelente.
# Sentimento: positive
# Confiança: 0.987
#
# A câmera é fantástica.
# Sentimento: positive
# Confiança: 0.922
#
# Não gostei do serviço.
# Sentimento: neutral
# Confiança: 0.504
#
# Muito ruim.
# Sentimento: negative
# Confiança: 0.696
#
# O celular estragou em dois dias.
# Sentimento: negative
# Confiança: 0.426
#
# Excelente custo-benefício.
# Sentimento: positive
# Confiança: 0.978
#
# Jamais compraria novamente.
# Sentimento: positive
# Confiança: 0.611

# %%
avaliacoes = [
  "Produto maravilhoso.",
  "Péssima qualidade.",
  "Gostei bastante.",
  "Não recomendo.",
  "Entrega muito rápida.",
  "A bateria dura pouco."
]

for avaliacao in avaliacoes:
    resultado = sentimentos(avaliacao)[0]
    print("-"*60)
    print(avaliacao)
    print(resultado)
# Out:
# ------------------------------------------------------------
# Produto maravilhoso.
# {'label': 'positive', 'score': 0.9457627534866333}
# ------------------------------------------------------------
# Péssima qualidade.
# {'label': 'positive', 'score': 0.8167737126350403}
# ------------------------------------------------------------
# Gostei bastante.
# {'label': 'positive', 'score': 0.5542794466018677}
# ------------------------------------------------------------
# Não recomendo.
# {'label': 'neutral', 'score': 0.5299525260925293}
# ------------------------------------------------------------
# Entrega muito rápida.
# {'label': 'positive', 'score': 0.939164400100708}
# ------------------------------------------------------------
# A bateria dura pouco.
# {'label': 'neutral', 'score': 0.5001692175865173}

# %%
texto = "O notebook é muito bom, mas a bateria deixa a desejar."
r = sentimentos(texto)[0]
print("Texto:")
print(texto)
print()
print("Classe:", r["label"])
print("Confiança:", round(r["score"]*100,2),"%")
# Out:
# Texto:
# O notebook é muito bom, mas a bateria deixa a desejar.
#
# Classe: positive
# Confiança: 48.04 %

# %%
while True:
    frase = input("Digite uma frase (ENTER para sair): ")
    if frase == "":
        break
    r = sentimentos(frase)[0]
    print()
    print("Sentimento:", r["label"])
    print("Confiança:", round(r["score"]*100,2),"%")
    print()
# Out:
# Digite uma frase (ENTER para sair): ruim
#
# Sentimento: positive
# Confiança: 69.39 %
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_8775/1117856596.py in <cell line: 0>()
#       1 while True:
# ----> 2     frase = input("Digite uma frase (ENTER para sair): ")
#       3     if frase == "":
#       4         break
#       5     r = sentimentos(frase)[0]
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
